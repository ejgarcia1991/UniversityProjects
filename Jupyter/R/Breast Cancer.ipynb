# %% [markdown]
# ## Diagnosing breast cancer with k-NN
# We will use the "Breast Cancer Wisconsin Diagnostic" dataset from the UCI Machine Learning Repository, which is available at http://archive.ics.uci.edu/ml.
#
# The breast cancer data includes 569 examples of cancer biopsies, each with 32 features. One feature is an identification number, another is the cancer diagnosis, and 30 are numeric-valued laboratory measurements. The diagnosis is coded as M to indicate malignant or B to indicate benign.

# %% [markdown]
# ### Import data file

# %%
# Local directory - use your own!!!!!!
setwd("C:/Users/Eilder Jorge/Documents/R Projects")

# %%
# Load data
wbcd <- read.csv("wisc_bc_data.csv", stringsAsFactors = FALSE)
# Examine the structure of the wbcd data frame
str(wbcd)
wbcd
# Out:
# 'data.frame':	569 obs. of  32 variables:
#  $ id               : int  87139402 8910251 905520 868871 9012568 906539 925291 87880 862989 89827 ...
#  $ diagnosis        : chr  "B" "B" "B" "B" ...
#  $ radius_mean      : num  12.3 10.6 11 11.3 15.2 ...
#  $ texture_mean     : num  12.4 18.9 16.8 13.4 13.2 ...
#  $ perimeter_mean   : num  78.8 69.3 70.9 73 97.7 ...
#  $ area_mean        : num  464 346 373 385 712 ...
#  $ smoothness_mean  : num  0.1028 0.0969 0.1077 0.1164 0.0796 ...
#  $ compactness_mean : num  0.0698 0.1147 0.078 0.1136 0.0693 ...
#  $ concavity_mean   : num  0.0399 0.0639 0.0305 0.0464 0.0339 ...
#  $ points_mean      : num  0.037 0.0264 0.0248 0.048 0.0266 ...
#  $ symmetry_mean    : num  0.196 0.192 0.171 0.177 0.172 ...
#  $ dimension_mean   : num  0.0595 0.0649 0.0634 0.0607 0.0554 ...
#  $ radius_se        : num  0.236 0.451 0.197 0.338 0.178 ...
#  $ texture_se       : num  0.666 1.197 1.387 1.343 0.412 ...
#  $ perimeter_se     : num  1.67 3.43 1.34 1.85 1.34 ...
#  $ area_se          : num  17.4 27.1 13.5 26.3 17.7 ...
#  $ smoothness_se    : num  0.00805 0.00747 0.00516 0.01127 0.00501 ...
#  $ compactness_se   : num  0.0118 0.03581 0.00936 0.03498 0.01485 ...
#  $ concavity_se     : num  0.0168 0.0335 0.0106 0.0219 0.0155 ...
#  $ points_se        : num  0.01241 0.01365 0.00748 0.01965 0.00915 ...
#  $ symmetry_se      : num  0.0192 0.035 0.0172 0.0158 0.0165 ...
#  $ dimension_se     : num  0.00225 0.00332 0.0022 0.00344 0.00177 ...
#  $ radius_worst     : num  13.5 11.9 12.4 11.9 16.2 ...
#  $ texture_worst    : num  15.6 22.9 26.4 15.8 15.7 ...
#  $ perimeter_worst  : num  87 78.3 79.9 76.5 104.5 ...
#  $ area_worst       : num  549 425 471 434 819 ...
#  $ smoothness_worst : num  0.139 0.121 0.137 0.137 0.113 ...
#  $ compactness_worst: num  0.127 0.252 0.148 0.182 0.174 ...
#  $ concavity_worst  : num  0.1242 0.1916 0.1067 0.0867 0.1362 ...
#  $ points_worst     : num  0.0939 0.0793 0.0743 0.0861 0.0818 ...
#  $ symmetry_worst   : num  0.283 0.294 0.3 0.21 0.249 ...
#  $ dimension_worst  : num  0.0677 0.0759 0.0788 0.0678 0.0677 ...
# 569   9012795 M         21.370      15.10        141.30         1386.0
#     smoothness_mean compactness_mean concavity_mean points_mean ...
# 1   0.10280         0.06981          0.039870       0.037000    ...
# 2   0.09688         0.11470          0.063870       0.026420    ...
# 3   0.10770         0.07804          0.030460       0.024800    ...
# 4   0.11640         0.11360          0.046350       0.047960    ...
# 5   0.07963         0.06934          0.033930       0.026570    ...
# 6   0.08546         0.07722          0.054850       0.014280    ...
# 7   0.09261         0.10210          0.111200       0.041050    ...
# 8   0.13230         0.17680          0.155800       0.091760    ...
# 9   0.09989         0.08578          0.029950       0.012010    ...
# 10  0.10330         0.09097          0.053970       0.033410    ...
# 11  0.10850         0.16440          0.218800       0.112100    ...
# 12  0.08654         0.06679          0.038850       0.023310    ...
# 13  0.08675         0.10890          0.108500       0.035100    ...
# 14  0.08060         0.03789          0.000692       0.004167    ...
# 15  0.10320         0.09871          0.165500       0.090630    ...
# 16  0.08473         0.13300          0.102900       0.037360    ...
# 17  0.09462         0.09462          0.071350       0.059330    ...
# 18  0.10280         0.07664          0.031930       0.021070    ...
# 19  0.10800         0.18380          0.228300       0.128000    ...
# 20  0.10660         0.09509          0.028550       0.028820    ...
# 21  0.09774         0.06141          0.038090       0.032390    ...
# 22  0.12360         0.15520          0.045150       0.045310    ...
# 23  0.10040         0.07460          0.049440       0.029320    ...
# 24  0.11500         0.18070          0.113800       0.085340    ...
# 25  0.11220         0.13030          0.064760       0.030680    ...
# 26  0.10070         0.12800          0.077890       0.050690    ...
# 27  0.10220         0.08165          0.039740       0.027800    ...
# 28  0.10820         0.16970          0.168300       0.087510    ...
# 29  0.08481         0.09228          0.084220       0.022920    ...
# 30  0.07937         0.05696          0.021810       0.014730    ...
# ... ...             ...              ...            ...
# 540 0.08983         0.07525          0.04196        0.033500    ...
# 541 0.08772         0.07304          0.06950        0.053900    ...
# 542 0.13710         0.12250          0.03332        0.024210    ...
# 543 0.08393         0.04216          0.00186        0.002924    ...
# 544 0.11700         0.18750          0.25650        0.150400    ...
# 545 0.12860         0.34540          0.37540        0.160400    ...
# 546 0.10050         0.07943          0.06155        0.033700    ...
# 547 0.09462         0.12430          0.09263        0.023080    ...
# 548 0.09676         0.07952          0.02688        0.017810    ...
# 549 0.09929         0.11260          0.04462        0.043040    ...
# 550 0.10310         0.09092          0.06592        0.027490    ...
# 551 0.07551         0.08316          0.06126        0.018670    ...
# 552 0.07274         0.06064          0.04505        0.014710    ...
# 553 0.11860         0.23960          0.22730        0.085430    ...
# 554 0.10730         0.09713          0.05282        0.044400    ...
# 555 0.08791         0.05205          0.02772        0.020680    ...
# 556 0.11670         0.20870          0.28100        0.156200    ...
# 557 0.09345         0.05991          0.02638        0.020690    ...
# 558 0.10310         0.18360          0.14500        0.063000    ...
# 559 0.10060         0.05743          0.02363        0.025830    ...
# 560 0.09179         0.08890          0.04069        0.022600    ...
# 561 0.09823         0.10980          0.13190        0.055980    ...
# 562 0.08673         0.06545          0.01994        0.016920    ...
# 563 0.06995         0.05223          0.03476        0.017370    ...
# 564 0.11340         0.08834          0.03800        0.034000    ...
# 564 14.040       21.08          92.80           599.5     0.15470
# 565 14.900       23.89          95.10           687.6     0.12820
# 566 10.880       19.48          70.89           357.1     0.13600
# 567 17.800       28.03         113.80           973.1     0.13010
# 568 15.800       16.93         103.10           749.9     0.13470
# 569 22.690       21.84         152.10          1535.0     0.11920
#     compactness_worst concavity_worst points_worst symmetry_worst
# 1   0.12660           0.124200        0.09391      0.2827
# 2   0.25150           0.191600        0.07926      0.2940
# 3   0.14820           0.106700        0.07431      0.2998
# 4   0.18220           0.086690        0.08611      0.2102
# 5   0.17370           0.136200        0.08178      0.2487
# 6   0.19370           0.256000        0.06664      0.3035
# 7   0.25170           0.363000        0.09653      0.2112
# 8   0.52090           0.464600        0.20130      0.4432
# 9   0.14860           0.079870        0.03203      0.2826
# 10  0.22100           0.229900        0.10750      0.3301
# 11  0.35970           0.517900        0.21130      0.2480
# 12  0.17880           0.194300        0.08211      0.3113
# 13  0.35490           0.450400        0.11810      0.2563
# 14  0.06191           0.001845        0.01111      0.2439
# 15  0.18450           0.397700        0.14660      0.2293
# 16  0.31710           0.366200        0.11050      0.2258
# 17  0.19490           0.170900        0.13740      0.2723
# 18  0.12120           0.102000        0.05602      0.2688
# 19  0.33910           0.493200        0.19230      0.3294
# 20  0.25850           0.099150        0.08187      0.3469
# 21  0.10400           0.152100        0.10990      0.2572
# 22  0.32510           0.139500        0.13080      0.2803
# 23  0.16440           0.141200        0.07887      0.2251
# 24  0.28830           0.196000        0.14230      0.2590
# 25  0.20490           0.129500        0.06136      0.2383
# 26  0.35420           0.277900        0.13830      0.2589
# 27  0.17510           0.138100        0.07911      0.2678
# 28  0.61100           0.633500        0.20240      0.4027
# 29  0.34160           0.434100        0.08120      0.2982
# 30  0.16760           0.136400        0.06987      0.2741
# ... ...               ...             ...          ...
# 540 0.18510           0.192200        0.084490     0.2772
# 541 0.14860           0.193200        0.109600     0.3275
# 542 0.20970           0.099960        0.072620     0.3681
# 543 0.06624           0.005579        0.008772     0.2505
# 544 0.44920           0.534400        0.268500     0.5558
# 545 0.61640           0.768100        0.250800     0.5440
# 546 0.20680           0.224100        0.105600     0.3380
# 547 0.18790           0.154400        0.038460     0.1652
# 548 0.18390           0.125500        0.083120     0.2744
# 549 0.22640           0.132600        0.104800     0.2250
# 550 0.21560           0.305000        0.065480     0.2747
# 551 0.19360           0.183800        0.056010     0.2488
# 552 0.12560           0.120100        0.039220     0.2576
# 553 1.05800           1.105000        0.221000     0.4366
# 554 0.18540           0.136600        0.101000     0.2478
# 555 0.10630           0.139000        0.060050     0.2444
# 556 0.57170           0.705300        0.242200     0.3828
# 557 0.10490           0.081050        0.065440     0.2740
# 558 0.36350           0.321900        0.110800     0.2827
# 559 0.08240           0.039380        0.043060     0.1902
# 560 0.18810           0.206000        0.083080     0.3600
# 561 0.42380           0.518600        0.144700     0.3591
# 562 0.19280           0.116700        0.055560     0.2661
# 563 0.14600           0.147200        0.055630     0.2345
# 564 0.22310           0.179100        0.115500     0.2382
# 565 0.19650           0.187600        0.104500     0.2235
# 566 0.16360           0.071620        0.040740     0.2434
# 567 0.32990           0.363000        0.122600     0.3175
# 568 0.14780           0.137300        0.106900     0.2606
# 569 0.28400           0.402400        0.196600     0.2730
#     dimension_worst
# 1   0.06771
# 2   0.07587
# 3   0.07881
# 4   0.06784
# 5   0.06766
# 6   0.08284
# 7   0.08732
# 8   0.10860
# 9   0.07552
# 10  0.09080
# 11  0.08999
# 12  0.08132
# 13  0.08174
# 14  0.06289
# 15  0.06091
# 16  0.08004
# 17  0.07071
# 18  0.06888
# 19  0.09469
# 20  0.09241
# 21  0.07097
# 22  0.09970
# 23  0.07732
# 24  0.07779
# 25  0.09026
# 26  0.10300
# 27  0.06603
# 28  0.09876
# 29  0.09825
# 30  0.07582
# ... ...
# 540 0.08756
# 541 0.06469
# 542 0.08982
# 543 0.06431
# 544 0.10240
# 545 0.09964
# 546 0.09584
# 547 0.07722
# 548 0.07238
# 549 0.08321
# 550 0.08301
# 551 0.08151
# 552 0.07018
# 553 0.20750
# 554 0.07757
# 555 0.06788
# 556 0.10070
# 557 0.06487
# 558 0.09208
# 559 0.07313
# 560 0.07285
# 561 0.10140
# 562 0.07961
# 563 0.06464
# 564 0.08553
# 565 0.06925
# 566 0.08488
# 567 0.09772
# 568 0.07810
# 569 0.08666

# %% [markdown]
# ### Preprocess data

# %%
# Drop the id feature
wbcd <- wbcd[,-1]

# %%
# Table of diagnosis
table(wbcd$diagnosis)
# Out:
#   B   M
# 357 212

# %%
# Recode diagnosis as a factor
wbcd$diagnosis <- factor(wbcd$diagnosis, levels = c("B", "M"), labels = c("Benign", "Malignant"))
table(wbcd$diagnosis)
# Out:
#    Benign Malignant
#       357       212

# %%
# Table or proportions with more informative labels
round(prop.table(table(wbcd$diagnosis)) * 100, digits = 1)
# Out:
#    Benign Malignant
#      62.7      37.3

# %%
# Summarize three numeric features
summary(wbcd[,c("radius_mean", "area_mean", "smoothness_mean")])
# Out:
#   radius_mean       area_mean      smoothness_mean
#  Min.   : 6.981   Min.   : 143.5   Min.   :0.05263
#  1st Qu.:11.700   1st Qu.: 420.3   1st Qu.:0.08637
#  Median :13.370   Median : 551.1   Median :0.09587
#  Mean   :14.127   Mean   : 654.9   Mean   :0.09636
#  3rd Qu.:15.780   3rd Qu.: 782.7   3rd Qu.:0.10530
#  Max.   :28.110   Max.   :2501.0   Max.   :0.16340

# %%
# Normalize the wbcd data
wbcd_n <- as.data.frame(lapply(wbcd[,2:31], scale, center = TRUE, scale = TRUE))
# Confirm that normalization worked
summary(wbcd_n[,c("radius_mean", "area_mean", "smoothness_mean")])
boxplot(wbcd_n[,c("radius_mean", "area_mean", "smoothness_mean")])
# Out:
#   radius_mean        area_mean       smoothness_mean
#  Min.   :-2.0279   Min.   :-1.4532   Min.   :-3.10935
#  1st Qu.:-0.6888   1st Qu.:-0.6666   1st Qu.:-0.71034
#  Median :-0.2149   Median :-0.2949   Median :-0.03486
#  Mean   : 0.0000   Mean   : 0.0000   Mean   : 0.00000
#  3rd Qu.: 0.4690   3rd Qu.: 0.3632   3rd Qu.: 0.63564
#  Max.   : 3.9678   Max.   : 5.2459   Max.   : 4.76672
# plot without title

# %% [markdown]
# ### Visualize data

# %%
plot(wbcd[,2:5])
# Out:
# plot without title

# %%
plot(wbcd_n[,1:4], col=wbcd[,1])
# Out:
# plot without title

# %%
# Try with ggplot2!

# %%
cor(wbcd[,2:5])
# Out:
#                radius_mean texture_mean perimeter_mean area_mean
# radius_mean    1.0000000   0.3237819    0.9978553      0.9873572
# texture_mean   0.3237819   1.0000000    0.3295331      0.3210857
# perimeter_mean 0.9978553   0.3295331    1.0000000      0.9865068
# area_mean      0.9873572   0.3210857    0.9865068      1.0000000

# %%
cor(wbcd_n[,1:4])
# Out:
#                radius_mean texture_mean perimeter_mean area_mean
# radius_mean    1.0000000   0.3237819    0.9978553      0.9873572
# texture_mean   0.3237819   1.0000000    0.3295331      0.3210857
# perimeter_mean 0.9978553   0.3295331    1.0000000      0.9865068
# area_mean      0.9873572   0.3210857    0.9865068      1.0000000

# %% [markdown]
# ### Create training and test datasets

# %%
# Create training and test data
shuffle_ds <- sample(dim(wbcd_n)[1])
eightypct <- (dim(wbcd_n)[1] * 80) %/% 100
wbcd_train <- wbcd_n[shuffle_ds[1:eightypct], ]
wbcd_test <- wbcd_n[shuffle_ds[(eightypct+1):dim(wbcd_n)[1]], ]

# Create labels for training and test data
wbcd_train_labels <- wbcd[shuffle_ds[1:eightypct], 1]
wbcd_test_labels <- wbcd[shuffle_ds[(eightypct+1):dim(wbcd_n)[1]], 1]
# Out:
# [1] 30

# %% [markdown]
# ### Training a model on the data - By hand...

# %%
# Load the "class" library
library(class)
wbcd_test_pred <- knn(train = wbcd_train, test = wbcd_test, cl = wbcd_train_labels, k=21)
wbcd_test_pred
# Out:
#   [1] M B B M M B M B M B B B B B B M M B B B B M M B B B B B M B B M B M M B B
#  [38] B B B M B B B B B M B B B B B B B B M M M B B B B M M B M M B B M M B M B
#  [75] B B B B M B B B B B B B B B B B B B M B M M B M M M B B B B B M B B B B M
# [112] B B B
# Levels: B M

# %%
# Evaluating model performance
table(wbcd_test_pred,wbcd_test_labels)
# Out:
#               wbcd_test_labels
# wbcd_test_pred Benign Malignant
#      Benign        70         4
#      Malignant      0        40

# %% [markdown]
# ### Training a model on the data - Using caret...

# %%
require(caret)
knnModel <- train(x = wbcd_train, y = wbcd_train_labels, method = "knn")
class(knnModel)
knnModel
# Out:
# Loading required package: caret
# Loading required package: lattice
# Loading required package: ggplot2
# Warning message in load(system.file("models", "models.RData", package = "caret")):
# "strings not representable in native encoding will be translated to UTF-8"
# [1] "train"
# k-Nearest Neighbors
#
# 455 samples
#  30 predictor
#   2 classes: 'Benign', 'Malignant'
#
# No pre-processing
# Resampling: Bootstrapped (25 reps)
# Summary of sample sizes: 455, 455, 455, 455, 455, 455, ...
# Resampling results across tuning parameters:
#
#   k  Accuracy   Kappa
#   5  0.9590213  0.9103819
#   7  0.9609166  0.9144237
#   9  0.9605819  0.9134966
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was k = 7.

# %%
knnModel <- train(wbcd_train, wbcd_train_labels, method="knn", metric="Accuracy", tuneGrid = data.frame(.k=1:15))
knnModel
# Out:
# k-Nearest Neighbors
#
# 455 samples
#  30 predictor
#   2 classes: 'Benign', 'Malignant'
#
# No pre-processing
# Resampling: Bootstrapped (25 reps)
# Summary of sample sizes: 455, 455, 455, 455, 455, 455, ...
# Resampling results across tuning parameters:
#
#   k   Accuracy   Kappa
#    1  0.9508270  0.8921851
#    2  0.9509971  0.8925050
#    3  0.9572554  0.9059264
#    4  0.9541492  0.8993297
#    5  0.9541941  0.8990277
#    6  0.9540446  0.8981904
#    7  0.9580767  0.9072962
#    8  0.9590319  0.9091117
#    9  0.9575753  0.9062150
#   10  0.9589285  0.9089479
#   11  0.9574887  0.9059211
#   12  0.9577601  0.9064357
#   13  0.9572782  0.9054539
#   14  0.9568420  0.9044404
#   15  0.9544498  0.8990475
#
# Accuracy was used to select the optimal model using  the largest value.
# The final value used for the model was k = 8.

# %%
require(caret)
knnModel <- train(x = wbcd[shuffle_ds[1:eightypct],-1], y = wbcd[shuffle_ds[1:eightypct],1], method = "knn", preProc = c("center", "scale"))
class(knnModel)
knnModel
# Out:
# [1] "train"
# k-Nearest Neighbors
#
# 455 samples
#  30 predictor
#   2 classes: 'Benign', 'Malignant'
#
# Pre-processing: centered (30), scaled (30)
# Resampling: Bootstrapped (25 reps)
# Summary of sample sizes: 455, 455, 455, 455, 455, 455, ...
# Resampling results across tuning parameters:
#
#   k  Accuracy   Kappa
#   5  0.9491689  0.8888064
#   7  0.9499498  0.8907370
#   9  0.9516733  0.8942248
#
# Accuracy was used to select the optimal model using  the largest value.
# The final value used for the model was k = 9.

# %% [markdown]
# ### Predicting using the model

# %%
knnPred <- predict(knnModel, newdata = wbcd[shuffle_ds[(eightypct+1):dim(wbcd_n)[1]], -1])
knnPred
# Out:
#   [1] Benign    Benign    Malignant Malignant Malignant Benign    Benign
#   [8] Benign    Benign    Malignant Malignant Benign    Benign    Benign
#  [15] Benign    Benign    Malignant Benign    Malignant Malignant Benign
#  [22] Benign    Benign    Benign    Benign    Benign    Benign    Benign
#  [29] Benign    Benign    Malignant Malignant Benign    Benign    Malignant
#  [36] Benign    Benign    Benign    Benign    Benign    Benign    Benign
#  [43] Benign    Benign    Benign    Malignant Benign    Malignant Malignant
#  [50] Malignant Malignant Benign    Malignant Benign    Benign    Malignant
#  [57] Benign    Malignant Benign    Benign    Malignant Malignant Benign
#  [64] Benign    Malignant Malignant Malignant Benign    Benign    Benign
#  [71] Benign    Benign    Benign    Malignant Malignant Malignant Malignant
#  [78] Benign    Benign    Malignant Benign    Benign    Benign    Benign
#  [85] Benign    Benign    Malignant Malignant Malignant Malignant Benign
#  [92] Malignant Malignant Benign    Malignant Benign    Malignant Benign
#  [99] Malignant Benign    Benign    Benign    Benign    Malignant Benign
# [106] Malignant Benign    Benign    Benign    Benign    Benign    Malignant
# [113] Malignant Benign
# Levels: Benign Malignant

# %%
postResample(pred = knnPred, obs = wbcd[shuffle_ds[(eightypct+1):dim(wbcd_n)[1]], 1])
# Out:
#  Accuracy     Kappa
# 0.9824561 0.9626719

# %% [markdown]
# ## Exercise
# Try with different k choices and do a quick comparison. You can draw a plot to show the results.
